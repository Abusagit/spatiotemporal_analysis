# %%
import numpy as np
import pandas as pd
import plotly.express as px

from pathlib import Path

DATA_DIR = Path("../data/")

# %% [markdown]
# ## Numpy

# %% [markdown]
# ## Dimensionality of data

# %%
def read_dataset_file(path: Path) -> np.lib.npyio.NpzFile:
    return np.load(file=path, allow_pickle=True)

metr_la = read_dataset_file(DATA_DIR / "metr_la_new.npz")
metr_la
# Out:
# NpzFile '../data/metr_la_new.npz' with keys: num_timestamps, num_nodes, first_timestamp_datetime, last_timestamp_datetime, timestamp_frequency...

# %%
EDGES_KEY = "edges"
TARGETS_KEY = "targets"
SPATIAL_FEATURES_KEY = "spatial_node_features"

# %%
metr_la[EDGES_KEY]
# Out:
# array([[  0,  37],
#        [  0,  54],
#        [  0, 116],
#        ...,
#        [206, 155],
#        [206, 159],
#        [206, 163]], dtype=int32)

# %%
metr_la_targets = metr_la[TARGETS_KEY]
metr_la_targets.shape
# Out:
# (34272, 207)

# %%
timestamps = pd.date_range(start=metr_la["first_timestamp_datetime"].item(),
                           end=metr_la["last_timestamp_datetime"].item(),
                           freq="5min",
                           )
timestamps
# Out:
# DatetimeIndex(['2012-03-01 00:00:00', '2012-03-01 00:05:00',
#                '2012-03-01 00:10:00', '2012-03-01 00:15:00',
#                '2012-03-01 00:20:00', '2012-03-01 00:25:00',
#                '2012-03-01 00:30:00', '2012-03-01 00:35:00',
#                '2012-03-01 00:40:00', '2012-03-01 00:45:00',
#                ...
#                '2012-06-27 23:10:00', '2012-06-27 23:15:00',
#                '2012-06-27 23:20:00', '2012-06-27 23:25:00',
#                '2012-06-27 23:30:00', '2012-06-27 23:35:00',
#                '2012-06-27 23:40:00', '2012-06-27 23:45:00',
#                '2012-06-27 23:50:00', '2012-06-27 23:55:00'],
#               dtype='datetime64[ns]', length=34272, freq='5T')

# %%
node_index = 0
targets_mean_across_nodes = np.nanmean(metr_la_targets, axis=1)
targets_std_across_nodes = np.nanstd(metr_la_targets, axis = 1)
targets_median_across_nodes = np.nanmedian(metr_la_targets, axis= 1)
px.line(y=metr_la_targets[:, 0], x=timestamps, title=f"Node {node_index}, timestamps")
px.line(y = [targets_median_across_nodes, targets_mean_across_nodes],
        x = timestamps)
# Out:
# /var/folders/mv/gtq3ystx3nq9yk4kdtmz8rgr0000gn/T/ipykernel_21832/2251943040.py:2: RuntimeWarning: Mean of empty slice
#   targets_mean_across_nodes = np.nanmean(metr_la_targets, axis=1)
# /Users/artem/python/.venv/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /var/folders/mv/gtq3ystx3nq9yk4kdtmz8rgr0000gn/T/ipykernel_21832/2251943040.py:4: RuntimeWarning: All-NaN slice encountered
#   targets_median_across_nodes = np.nanmedian(metr_la_targets, axis= 1)

# %%
# %pip install networkx
# Out:
# Requirement already satisfied: networkx in /Users/artem/python/.venv/lib/python3.9/site-packages (3.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx

# %%
# !pip install torch==2.4.0
# Out:
# Collecting torch==2.4.0
#   Downloading torch-2.4.0-cp39-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /Users/artem/python/.venv/lib/python3.9/site-packages (from torch==2.4.0) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/artem/python/.venv/lib/python3.9/site-packages (from torch==2.4.0) (4.12.2)
# Requirement already satisfied: sympy in /Users/artem/python/.venv/lib/python3.9/site-packages (from torch==2.4.0) (1.13.1)
# Requirement already satisfied: networkx in /Users/artem/python/.venv/lib/python3.9/site-packages (from torch==2.4.0) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/artem/python/.venv/lib/python3.9/site-packages (from torch==2.4.0) (3.1.5)
# Requirement already satisfied: fsspec in /Users/artem/python/.venv/lib/python3.9/site-packages (from torch==2.4.0) (2025.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/artem/python/.venv/lib/python3.9/site-packages (from jinja2->torch==2.4.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/artem/python/.venv/lib/python3.9/site-packages (from sympy->torch==2.4.0) (1.3.0)
# Downloading torch-2.4.0-cp39-none-macosx_11_0_arm64.whl (62.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 MB 2.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0
#     Uninstalling torch-2.6.0:
#       Successfully uninstalled torch-2.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.21.0 requires torch==2.6.0, but you have torch 2.4.0 which is incompatible.
# Successfully installed torch-2.4.0

# %%
import torch
